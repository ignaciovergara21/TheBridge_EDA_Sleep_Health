# %% [markdown]
# EDA: Sleep health and lifestyle
#
# H1: El estrés afecta de forma negativa a la calidad del sueño.
#
# H2: La actividad física contribuye a mejor calidad del sueño(ver si puede contribuir tambien a reducir el estrés y que las 3 variables se relacionen entre ellas).
#
# H3: Los trastornos del sueño pueden estar asociados a factores clave del estilo de vida como la actividad física, el peso, la ocupación laboral o el estrés
